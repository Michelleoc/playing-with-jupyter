# %%
i = 1
j = 2

# %%
k = i + j

# %%
k
# Out:
# 3

# %% [markdown]
# # I am a heading
#
# - I am a list
# - I am a list
# - I am the third item
#
# ![](![image.png](attachment:6c22876c-6ed7-479c-b70f-1939f5ff58cf.png)
#
# **Bold text**

# %%
![](https://assets.mydogsname.com/images/categories/003-dog.png)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![](https://assets.mydogsname.com/images/categories/003-dog.png)

# %% [markdown]
# ![](https://assets.mydogsname.com/images/categories/003-dog.png)
